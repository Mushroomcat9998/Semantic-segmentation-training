# %%
# !nvidia-smi
# Out:
# Fri Dec  3 15:26:59 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8    30W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/【HNG017】Kompasu/Document/data/CC_dataset_full_for_train.zip' -d '/content/'
import os
os.rename('/content/CC_dataset_full_for_train', '/content/data')

# %%
# !git clone https://github.com/Mushroomcat9998/Semantic-segmentation-training
# %cd Semantic-segmentation-training
# Out:
# Cloning into 'Semantic-segmentation-training'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 12 (delta 0), reused 9 (delta 0), pack-reused 0
# Unpacking objects: 100% (12/12), done.
# /content/Semantic-segmentation-training

# %%
# !python train.py --data-path '/content/data' -b 4 -j 2 \
--epochs 100 \
--print-freq 50 \
--resume '/content/drive/MyDrive/【HNG017】Kompasu/colab/Deeplabv3_mbnv3/exp6/last.pth' \
--output-dir '/content/drive/MyDrive/【HNG017】Kompasu/colab/Deeplabv3_mbnv3/exp7' \
--model deeplabv3_mobilenet_v3_large \
--aux-loss --wd 0.000001 \
# Out:
# Not using distributed mode
# Namespace(amp=False, aux_loss=True, batch_size=4, data_path='/content/data', dataset='coco', device='cuda', dist_url='env://', distributed=False, epochs=100, lr=0.01, lr_warmup_decay=0.01, lr_warmup_epochs=0, lr_warmup_method='linear', model='deeplabv3_mobilenet_v3_large', momentum=0.9, output_dir='/content/drive/MyDrive/【HNG017】Kompasu/colab/Deeplabv3_mbnv3/exp7', pretrained=False, print_freq=50, resume='/content/drive/MyDrive/【HNG017】Kompasu/colab/Deeplabv3_mbnv3/exp6/last.pth', start_epoch=0, test_only=False, weight_decay=1e-06, weights=None, workers=2, world_size=1)
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Downloading: "https://download.pytorch.org/models/mobilenet_v3_large-8738ca79.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v3_large-8738ca79.pth
# 100% 21.1M/21.1M [00:00<00:00, 66.6MB/s]
# ...

# %%
# !python train.py --data-path '/content/data' -b 4 -j 2 \
--epochs 100 \
--print-freq 50 \
-- resume'' \
--output-dir '/content/drive/MyDrive/【HNG017】Kompasu/colab/Deeplabv3_mbnv3/exp' \
--model deeplabv3_mobilenet_v3_large \
--aux-loss --wd 0.000001 \
# Out:
# Not using distributed mode
# Namespace(amp=False, aux_loss=True, batch_size=4, data_path='/content/data', dataset='coco', device='cuda', dist_url='env://', distributed=False, epochs=100, lr=0.01, lr_warmup_decay=0.01, lr_warmup_epochs=0, lr_warmup_method='linear', model='deeplabv3_mobilenet_v3_large', momentum=0.9, output_dir='/content/drive/MyDrive/【HNG017】Kompasu/colab/Deeplabv3_mbnv3/exp', pretrained=False, print_freq=50, resume='', start_epoch=0, test_only=False, weight_decay=1e-06, weights=None, workers=2, world_size=1)
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Downloading: "https://download.pytorch.org/models/mobilenet_v3_large-8738ca79.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v3_large-8738ca79.pth
# 100% 21.1M/21.1M [00:00<00:00, 101MB/s]
# ...
